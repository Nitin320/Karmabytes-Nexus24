# %%
# !pip install cvzone
# Out:
# ^C
# Collecting cvzone
#   Downloading cvzone-1.6.1.tar.gz (25 kB)
# Collecting opencv-python
#   Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# Collecting numpy
#   Downloading numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
# Using legacy 'setup.py install' for cvzone, since package 'wheel' is not installed.
# Installing collected packages: numpy, opencv-python, cvzone
#     Running setup.py install for cvzone: started
#     Running setup.py install for cvzone: finished with status 'done'
# Successfully installed cvzone-1.6.1 numpy-1.26.4 opencv-python-4.9.0.80
# WARNING: You are using pip version 20.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\users\lenovo\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install te

# %%
import os
import cv2
import cvzone
from cvzone.ClassificationModule import Classifier

# %%
classifier = Classifier('Resources/Model/keras_model.h5')

# Load waste and bin images
imgWasteList = [cv2.imread(os.path.join('Resources/Waste', path), cv2.IMREAD_UNCHANGED) for path in os.listdir('Resources/Waste')]
imgBinsList = [cv2.imread(os.path.join('Resources/Bins', path), cv2.IMREAD_UNCHANGED) for path in os.listdir('Resources/Bins')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/ops/operation.py:208, in Operation.from_config(cls, config)
#     207 try:
# --> 208     return cls(**config)
#     209 except Exception as e:
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/depthwise_conv2d.py:118, in DepthwiseConv2D.__init__(self, kernel_size, strides, padding, depth_multiplier, data_format, dilation_rate, activation, use_bias, depthwise_initializer, bias_initializer, depthwise_regularizer, bias_regularizer, activity_regularizer, depthwise_constraint, bias_constraint, **kwargs)
#      99 def __init__(
#     100     self,
#     101     kernel_size,
#    (...)
#     116     **kwargs
#     117 ):
# --> 118     super().__init__(
#     119         rank=2,
#     120         depth_multiplier=depth_multiplier,
#     121         kernel_size=kernel_size,
#     122         strides=strides,
#     123         padding=padding,
#     124         data_format=data_format,
#     125         dilation_rate=dilation_rate,
#     126         activation=activation,
#     127         use_bias=use_bias,
#     128         depthwise_initializer=depthwise_initializer,
#     129         bias_initializer=bias_initializer,
#     130         depthwise_regularizer=depthwise_regularizer,
#     131         bias_regularizer=bias_regularizer,
#     132         activity_regularizer=activity_regularizer,
#     133         depthwise_constraint=depthwise_constraint,
#     134         bias_constraint=bias_constraint,
#     135         **kwargs
#     136     )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_depthwise_conv.py:106, in BaseDepthwiseConv.__init__(self, rank, depth_multiplier, kernel_size, strides, padding, data_format, dilation_rate, activation, use_bias, depthwise_initializer, bias_initializer, depthwise_regularizer, bias_regularizer, activity_regularizer, depthwise_constraint, bias_constraint, trainable, name, **kwargs)
#      84 def __init__(
#      85     self,
#      86     rank,
#    (...)
#     104     **kwargs,
#     105 ):
# --> 106     super().__init__(
#     107         trainable=trainable,
#     108         name=name,
#     109         activity_regularizer=regularizers.get(activity_regularizer),
#     110         **kwargs,
#     111     )
#     112     self.rank = rank
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/layers/layer.py:263, in Layer.__init__(self, activity_regularizer, trainable, dtype, autocast, name, **kwargs)
#     262 if kwargs:
# --> 263     raise ValueError(
#     264         "Unrecognized keyword arguments "
#     265         f"passed to {self.__class__.__name__}: {kwargs}"
#     266     )
#     268 self.built = False
#
# ValueError: Unrecognized keyword arguments passed to DepthwiseConv2D: {'groups': 1}
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 classifier = Classifier('Resources/Model/keras_model.h5')
#       3 # Load waste and bin images
#       4 imgWasteList = [cv2.imread(os.path.join('Resources/Waste', path), cv2.IMREAD_UNCHANGED) for path in os.listdir('Resources/Waste')]
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/cvzone/ClassificationModule.py:29, in Classifier.__init__(self, modelPath, labelsPath)
#      26 np.set_printoptions(suppress=True)  # Disable scientific notation for clarity
#      28 # Load the Keras model
# ---> 29 self.model = tensorflow.keras.models.load_model(self.model_path)
#      31 # Create a NumPy array with the right shape to feed into the Keras model
#      32 self.data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/saving/saving_api.py:183, in load_model(filepath, custom_objects, compile, safe_mode)
#     176     return saving_lib.load_model(
#     177         filepath,
#     178         custom_objects=custom_objects,
#     179         compile=compile,
#     180         safe_mode=safe_mode,
#     181     )
#     182 if str(filepath).endswith((".h5", ".hdf5")):
# --> 183     return legacy_h5_format.load_model_from_hdf5(filepath)
#     184 elif str(filepath).endswith(".keras"):
#     185     raise ValueError(
#     186         f"File not found: filepath={filepath}. "
#     187         "Please ensure the file is an accessible `.keras` "
#     188         "zip file."
#     189     )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/legacy_h5_format.py:133, in load_model_from_hdf5(filepath, custom_objects, compile)
#     130 model_config = json_utils.decode(model_config)
#     132 with saving_options.keras_option_scope(use_legacy_config=True):
# --> 133     model = saving_utils.model_from_config(
#     134         model_config, custom_objects=custom_objects
#     135     )
#     137     # set weights
#     138     load_weights_from_hdf5_group(f["model_weights"], model)
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/models/sequential.py:330, in Sequential.from_config(cls, config, custom_objects)
#     326 for layer_config in layer_configs:
#     327     if "module" not in layer_config:
#     328         # Legacy format deserialization (no "module" key)
#     329         # used for H5 and SavedModel formats
# --> 330         layer = saving_utils.model_from_config(
#     331             layer_config,
#     332             custom_objects=custom_objects,
#     333         )
#     334     else:
#     335         layer = serialization_lib.deserialize_keras_object(
#     336             layer_config,
#     337             custom_objects=custom_objects,
#     338         )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/models/sequential.py:330, in Sequential.from_config(cls, config, custom_objects)
#     326 for layer_config in layer_configs:
#     327     if "module" not in layer_config:
#     328         # Legacy format deserialization (no "module" key)
#     329         # used for H5 and SavedModel formats
# --> 330         layer = saving_utils.model_from_config(
#     331             layer_config,
#     332             custom_objects=custom_objects,
#     333         )
#     334     else:
#     335         layer = serialization_lib.deserialize_keras_object(
#     336             layer_config,
#     337             custom_objects=custom_objects,
#     338         )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/models/model.py:513, in Model.from_config(cls, config, custom_objects)
#     508 if is_functional_config and revivable_as_functional:
#     509     # Revive Functional model
#     510     # (but not Functional subclasses with a custom __init__)
#     511     from keras.src.models.functional import functional_from_config
# --> 513     return functional_from_config(
#     514         cls, config, custom_objects=custom_objects
#     515     )
#     517 # Either the model has a custom __init__, or the config
#     518 # does not contain all the information necessary to
#     519 # revive a Functional model. This happens when the user creates
#    (...)
#     522 # In this case, we fall back to provide all config into the
#     523 # constructor of the class.
#     524 try:
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/models/functional.py:514, in functional_from_config(cls, config, custom_objects)
#     512 # First, we create all layers and enqueue nodes to be processed
#     513 for layer_data in config["layers"]:
# --> 514     process_layer(layer_data)
#     516 # Then we process nodes in order of layer depth.
#     517 # Nodes that cannot yet be processed (if the inbound node
#     518 # does not yet exist) are re-enqueued, and the process
#     519 # is repeated until all nodes are processed.
#     520 while unprocessed_nodes:
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/models/functional.py:494, in functional_from_config.<locals>.process_layer(layer_data)
#     490 # Instantiate layer.
#     491 if "module" not in layer_data:
#     492     # Legacy format deserialization (no "module" key)
#     493     # used for H5 and SavedModel formats
# --> 494     layer = saving_utils.model_from_config(
#     495         layer_data, custom_objects=custom_objects
#     496     )
#     497 else:
#     498     layer = serialization_lib.deserialize_keras_object(
#     499         layer_data, custom_objects=custom_objects
#     500     )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/serialization.py:504, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     502     else:
#     503         with object_registration.CustomObjectScope(custom_objects):
# --> 504             deserialized_obj = cls.from_config(cls_config)
#     505 else:
#     506     # Then `cls` may be a function returning a class.
#     507     # in this case by convention `config` holds
#     508     # the kwargs of the function.
#     509     custom_objects = custom_objects or {}
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/ops/operation.py:210, in Operation.from_config(cls, config)
#     208     return cls(**config)
#     209 except Exception as e:
# --> 210     raise TypeError(
#     211         f"Error when deserializing class '{cls.__name__}' using "
#     212         f"config={config}.\n\nException encountered: {e}"
#     213     )
#
# TypeError: Error when deserializing class 'DepthwiseConv2D' using config={'name': 'expanded_conv_depthwise', 'trainable': True, 'dtype': 'float32', 'kernel_size': [3, 3], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'linear', 'use_bias': False, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'bias_regularizer': None, 'activity_regularizer': None, 'bias_constraint': None, 'depth_multiplier': 1, 'depthwise_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'depthwise_regularizer': None, 'depthwise_constraint': None}.
#
# Exception encountered: Unrecognized keyword arguments passed to DepthwiseConv2D: {'groups': 1}

# %%
classDic = {0: None, 1: 0, 2: 0, 3: 3, 4: 3, 5: 1, 6: 1, 7: 2, 8: 2}

# Main loop
cap = cv2.VideoCapture(0)  # Initialize video capture object
imgArrow = cv2.imread('Resources/arrow.png', cv2.IMREAD_UNCHANGED)  # Load arrow image

# %%
while True:
    _, img = cap.read()  # Capture a frame from the video
    imgResize = cv2.resize(img, (454, 340))
    imgBackground = cv2.imread('Resources/background.jpg')

    # Get prediction from classifier
    predection = classifier.getPrediction(img)
    classID = predection[1]

    # Overlay waste image and arrow if class is not recyclable
    if classID != 0:
        imgBackground = cvzone.overlayPNG(imgBackground, imgWasteList[classID - 1], (909, 127))
        imgBackground = cvzone.overlayPNG(imgBackground, imgArrow, (978, 320))
        classIDBin = classDic[classID]

    # Overlay bin image
    imgBackground = cvzone.overlayPNG(imgBackground, imgBinsList[classIDBin], (895, 374))

    # Overlay resized input image
    imgBackground[148:148 + 340, 159:159 + 454] = imgResize

    # Display output
    cv2.imshow("Output", imgBackground)
    cv2.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 while True:
# ----> 2     _, img = cap.read()  # Capture a frame from the video
#       3     imgResize = cv2.resize(img, (454, 340))
#       4     imgBackground = cv2.imread('Resources/background.jpg')
#
# NameError: name 'cap' is not defined

# %%
# import cv2
import cvzone  # Importing the cvzone library

# Initialize the webcam
cap = cv2.VideoCapture(0)  # Capture video from the third webcam (0-based index)

# Main loop to continuously capture frames
while True:
    # Capture a single frame from the webcam
    success, img = cap.read()  # 'success' is a boolean that indicates if the frame was captured successfully, and 'img' contains the frame itself

    # Add a rectangle with styled corners to the image
    img = cvzone.cornerRect(
        img,  # The image to draw on
        (200, 200, 300, 200),  # The position and dimensions of the rectangle (x, y, width, height)
        l=30,  # Length of the corner edges
        t=5,  # Thickness of the corner edges
        rt=1,  # Thickness of the rectangle
        colorR=(255, 0, 255),  # Color of the rectangle
        colorC=(0, 255, 0)  # Color of the corner edges
    )

    # Show the modified image
    cv2.imshow("Image", img)  # Display the image in a window named "Image"

    # Wait for 1 millisecond between frames
    cv2.waitKey(1)  # Waits 1 ms for a key event (not being used here)

# %%
from cvzone.ClassificationModule import Classifier
import cv2

cap = cv2.VideoCapture(2)  # Initialize video capture
path = "Resources/Model"
maskClassifier = Classifier(f'{path}/keras_model.h5', f'{path}/labels.txt')

while True:
    _, img = cap.read()  # Capture frame-by-frame
    prediction = maskClassifier.getPrediction(img)
    print(prediction)  # Print prediction result
    cv2.imshow("Image", img)
    cv2.waitKey(1)  # Wait for a key press
# Out:
# OpenCV: out device of bound (0-0): 2
# OpenCV: camera failed to properly initialize!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/ops/operation.py:208, in Operation.from_config(cls, config)
#     207 try:
# --> 208     return cls(**config)
#     209 except Exception as e:
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/depthwise_conv2d.py:118, in DepthwiseConv2D.__init__(self, kernel_size, strides, padding, depth_multiplier, data_format, dilation_rate, activation, use_bias, depthwise_initializer, bias_initializer, depthwise_regularizer, bias_regularizer, activity_regularizer, depthwise_constraint, bias_constraint, **kwargs)
#      99 def __init__(
#     100     self,
#     101     kernel_size,
#    (...)
#     116     **kwargs
#     117 ):
# --> 118     super().__init__(
#     119         rank=2,
#     120         depth_multiplier=depth_multiplier,
#     121         kernel_size=kernel_size,
#     122         strides=strides,
#     123         padding=padding,
#     124         data_format=data_format,
#     125         dilation_rate=dilation_rate,
#     126         activation=activation,
#     127         use_bias=use_bias,
#     128         depthwise_initializer=depthwise_initializer,
#     129         bias_initializer=bias_initializer,
#     130         depthwise_regularizer=depthwise_regularizer,
#     131         bias_regularizer=bias_regularizer,
#     132         activity_regularizer=activity_regularizer,
#     133         depthwise_constraint=depthwise_constraint,
#     134         bias_constraint=bias_constraint,
#     135         **kwargs
#     136     )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_depthwise_conv.py:106, in BaseDepthwiseConv.__init__(self, rank, depth_multiplier, kernel_size, strides, padding, data_format, dilation_rate, activation, use_bias, depthwise_initializer, bias_initializer, depthwise_regularizer, bias_regularizer, activity_regularizer, depthwise_constraint, bias_constraint, trainable, name, **kwargs)
#      84 def __init__(
#      85     self,
#      86     rank,
#    (...)
#     104     **kwargs,
#     105 ):
# --> 106     super().__init__(
#     107         trainable=trainable,
#     108         name=name,
#     109         activity_regularizer=regularizers.get(activity_regularizer),
#     110         **kwargs,
#     111     )
#     112     self.rank = rank
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/layers/layer.py:263, in Layer.__init__(self, activity_regularizer, trainable, dtype, autocast, name, **kwargs)
#     262 if kwargs:
# --> 263     raise ValueError(
#     264         "Unrecognized keyword arguments "
#     265         f"passed to {self.__class__.__name__}: {kwargs}"
#     266     )
#     268 self.built = False
#
# ValueError: Unrecognized keyword arguments passed to DepthwiseConv2D: {'groups': 1}
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       4 cap = cv2.VideoCapture(2)  # Initialize video capture
#       5 path = "Resources/Model"
# ----> 6 maskClassifier = Classifier(f'{path}/keras_model.h5', f'{path}/labels.txt')
#       8 while True:
#       9     _, img = cap.read()  # Capture frame-by-frame
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/cvzone/ClassificationModule.py:29, in Classifier.__init__(self, modelPath, labelsPath)
#      26 np.set_printoptions(suppress=True)  # Disable scientific notation for clarity
#      28 # Load the Keras model
# ---> 29 self.model = tensorflow.keras.models.load_model(self.model_path)
#      31 # Create a NumPy array with the right shape to feed into the Keras model
#      32 self.data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/saving/saving_api.py:183, in load_model(filepath, custom_objects, compile, safe_mode)
#     176     return saving_lib.load_model(
#     177         filepath,
#     178         custom_objects=custom_objects,
#     179         compile=compile,
#     180         safe_mode=safe_mode,
#     181     )
#     182 if str(filepath).endswith((".h5", ".hdf5")):
# --> 183     return legacy_h5_format.load_model_from_hdf5(filepath)
#     184 elif str(filepath).endswith(".keras"):
#     185     raise ValueError(
#     186         f"File not found: filepath={filepath}. "
#     187         "Please ensure the file is an accessible `.keras` "
#     188         "zip file."
#     189     )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/legacy_h5_format.py:133, in load_model_from_hdf5(filepath, custom_objects, compile)
#     130 model_config = json_utils.decode(model_config)
#     132 with saving_options.keras_option_scope(use_legacy_config=True):
# --> 133     model = saving_utils.model_from_config(
#     134         model_config, custom_objects=custom_objects
#     135     )
#     137     # set weights
#     138     load_weights_from_hdf5_group(f["model_weights"], model)
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/models/sequential.py:330, in Sequential.from_config(cls, config, custom_objects)
#     326 for layer_config in layer_configs:
#     327     if "module" not in layer_config:
#     328         # Legacy format deserialization (no "module" key)
#     329         # used for H5 and SavedModel formats
# --> 330         layer = saving_utils.model_from_config(
#     331             layer_config,
#     332             custom_objects=custom_objects,
#     333         )
#     334     else:
#     335         layer = serialization_lib.deserialize_keras_object(
#     336             layer_config,
#     337             custom_objects=custom_objects,
#     338         )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/models/sequential.py:330, in Sequential.from_config(cls, config, custom_objects)
#     326 for layer_config in layer_configs:
#     327     if "module" not in layer_config:
#     328         # Legacy format deserialization (no "module" key)
#     329         # used for H5 and SavedModel formats
# --> 330         layer = saving_utils.model_from_config(
#     331             layer_config,
#     332             custom_objects=custom_objects,
#     333         )
#     334     else:
#     335         layer = serialization_lib.deserialize_keras_object(
#     336             layer_config,
#     337             custom_objects=custom_objects,
#     338         )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/models/model.py:513, in Model.from_config(cls, config, custom_objects)
#     508 if is_functional_config and revivable_as_functional:
#     509     # Revive Functional model
#     510     # (but not Functional subclasses with a custom __init__)
#     511     from keras.src.models.functional import functional_from_config
# --> 513     return functional_from_config(
#     514         cls, config, custom_objects=custom_objects
#     515     )
#     517 # Either the model has a custom __init__, or the config
#     518 # does not contain all the information necessary to
#     519 # revive a Functional model. This happens when the user creates
#    (...)
#     522 # In this case, we fall back to provide all config into the
#     523 # constructor of the class.
#     524 try:
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/models/functional.py:514, in functional_from_config(cls, config, custom_objects)
#     512 # First, we create all layers and enqueue nodes to be processed
#     513 for layer_data in config["layers"]:
# --> 514     process_layer(layer_data)
#     516 # Then we process nodes in order of layer depth.
#     517 # Nodes that cannot yet be processed (if the inbound node
#     518 # does not yet exist) are re-enqueued, and the process
#     519 # is repeated until all nodes are processed.
#     520 while unprocessed_nodes:
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/models/functional.py:494, in functional_from_config.<locals>.process_layer(layer_data)
#     490 # Instantiate layer.
#     491 if "module" not in layer_data:
#     492     # Legacy format deserialization (no "module" key)
#     493     # used for H5 and SavedModel formats
# --> 494     layer = saving_utils.model_from_config(
#     495         layer_data, custom_objects=custom_objects
#     496     )
#     497 else:
#     498     layer = serialization_lib.deserialize_keras_object(
#     499         layer_data, custom_objects=custom_objects
#     500     )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/legacy/saving/serialization.py:504, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     502     else:
#     503         with object_registration.CustomObjectScope(custom_objects):
# --> 504             deserialized_obj = cls.from_config(cls_config)
#     505 else:
#     506     # Then `cls` may be a function returning a class.
#     507     # in this case by convention `config` holds
#     508     # the kwargs of the function.
#     509     custom_objects = custom_objects or {}
#
# File ~/Documents/PycharmProjects/.venv/lib/python3.12/site-packages/keras/src/ops/operation.py:210, in Operation.from_config(cls, config)
#     208     return cls(**config)
#     209 except Exception as e:
# --> 210     raise TypeError(
#     211         f"Error when deserializing class '{cls.__name__}' using "
#     212         f"config={config}.\n\nException encountered: {e}"
#     213     )
#
# TypeError: Error when deserializing class 'DepthwiseConv2D' using config={'name': 'expanded_conv_depthwise', 'trainable': True, 'dtype': 'float32', 'kernel_size': [3, 3], 'strides': [1, 1], 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': [1, 1], 'groups': 1, 'activation': 'linear', 'use_bias': False, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'bias_regularizer': None, 'activity_regularizer': None, 'bias_constraint': None, 'depth_multiplier': 1, 'depthwise_initializer': {'class_name': 'VarianceScaling', 'config': {'scale': 1, 'mode': 'fan_avg', 'distribution': 'uniform', 'seed': None}}, 'depthwise_regularizer': None, 'depthwise_constraint': None}.
#
# Exception encountered: Unrecognized keyword arguments passed to DepthwiseConv2D: {'groups': 1}
